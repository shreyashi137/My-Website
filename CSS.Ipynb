# %% [markdown]
# **CSS** --> Cascading Style Sheet
# * It Is A Language That Is Used To Descibe The Style Of A Document

# %% [markdown]
# H1 --> Is Selector
#
# Color --> Property
#
# Red --> Value
#
#
# H1 {
#     Color:Red
# }

# %% [markdown]
# **InCluding Style**
#
# 1. Inline Style ---> **Display:Inline** Menas Je Je Ghali Ghali Yet Astil Te Yekach Line Madhe Yenar
#
# 2. Style Tag
#
# 3. External Stylesheet --> Writing CSS In A Seprate Document And Linking It With HTML File

# %% [markdown]
# 3. External Stylesheet--> Created Another File And GIve Name
# **Style.CSS**
#
# - Link These Two Files
# - In Head Tag -->
# - <Link rel="Stylesheet" href="Style.Css">
#
#
# - We Created This File Beacuse We Write All Our Colorfull Things In That File Only

# %% [markdown]
# # Color
#
# - RGB = Red Green Blue
# - Stop Until 255 --> 255-0-45(Like This)
#
#
# - Hex = Hexadecimal
# - 00-FF-00(#FF00FF Like This)
# - R -G -B

# %% [markdown]
# # Selector
#
# - **Universal Selector** -> *{}  (Change Every Leeters Of The Files Color)
#
# - **Element Selector** -> h1{}  ( Apply All Of The H1 Tags Only In That File)
#
# - **Id Selector**  -> #Any{}  ( Give Any Id Of That Particulra Thinsg You Want To Change)
#
# - **Class Selector** -> .Any{}

# %% [markdown]
# # Text Properties
#
# - **Text-Align** --> Left / Right / Center
#
# - **Text Decoration** -->  Underline/ Overline/ Line-Through
#
# - Text-Decoration:NOne (Menas Remove The Underline Of That Automaticlly Come In Link )
#
#
# - And If Any Dot Or Number Has Come In That Text In Front Also Remove Using **List-Style-Type:None**
#
#
#
# - **Font-Weight** --> Normal/Bold/Bolder/Lighter / 100-900
# (400 Is Bold More Then That Is Bolder)
#
# - **Font-Family** --> To Change The Font OF The Sentences
#
# - **Line-Height** --> Tell The Line Height
#
# - **Text-Transform** --> Uppercase/LowerCase/Capitalize/None

# %% [markdown]
# # Units In CSS
#
# - **Absoulte**
# - Pixels(Px)
#   96px = 1Inch
#   Font-Size:2Px

# %% [markdown]
# # Box Model
# - 1. Height --> Div{
#     Height:50px
# }
#
#
# - 2. Wdith --> Div{
#     Width:50Px
# }
#
#
# - 3. Border --> Border-Width:2px
#                 Border-Style:Solid/Dotted/Dashed
#                 Border-Color:Black;
#
#                 **Shortcut** --> Of Above Three 3 In One
#                 Border: 2px solid Black
#
#
# Border Userd **ROund The Corners** --->
# Border-Radius:10px --->     Small Kam Round
# Border-Radius:50%  ---> If The Height And Width Same Then Used 50% So Its Create **Round**
#
#
#
# - 4. Padding ---> Jo Content Hai Box Ke Andar Uska Chage Karne KE Liye
#    - Padding-Left
#    - Padding-Right
#    - Padding-Top
#    - Padding-Bottom
#
#    **Shortcut** --> Padding : 1px  2px   3px    4px;
#                               Top |Right|Bottom|Left|     (Clockwise)
#
#
#
#
# - 5. Margin----> 2 Boxis Ka Area
#     - Margin-Right
#     - Margin-Left
#     - Margin-TOp
#     - Margin-Bottom
#
#     **Shortcut** --> Margin: 1px 2px 3px 4px;
#                             Top |Right|Bottom|Left|     (Clockwise)

# %% [markdown]
# # Display Property
#
# Display : Inline/ Block / Inline-Block/ None
#
#
# **Inline** - Takes Only The Space Requirex By The Element. (No Margin/ Padding)
#
# **Block** - Takes Full Space Availble In Width
#
# **Inline-Block** - Similar To Inline But Wr Can Set Margin And Padding
#
# **None** - TO Remove Element From Document Flow
#
# # Visibility
#
# - Visibility : Hidden;
#
# Note: When Visibility Is Set To None , Space For The Element Is Reserved But For Diaply Set TO None, No Space Is Reserved Or Blocked For The Elements

# %% [markdown]
# # Alpha Channel
#
# - Opacity (0-1)
#
# - **RGBA**
#
# Color: Rgba(255,0,0,0.5)  Light Color
#
# Color: Rgba(255,0,0,1) Dark Color

# %% [markdown]
# <!-- Level 3 -->
#
# # Units In CSS
#
# - **Relative**
#
# - **%**--> Size As Relative TO An Element's Parent Objet
#                 Width : 33%
#                 Margin-Left : 50%
#
#
#
# - **em**--> Em This One Double The Parent Element Size
#
#
#
# - **rem**--> Outer Element Size
#
# -**Vh** --> Jevdi Screen Ahe Tevd Occupied Karty (View Height)
#
# - **Vw** --> Same Has Vh But Width (View Width)

# %% [markdown]
# # Position
#
# - The Posotion CSS Property Sets **How An Element Is Positioned** In A Document
#
# - Position: Static / Relative / Absoulte / Fixed / S
#
#
#
# - 1. **Static** --> Defualt Position (The Top,Right,Bottom,Left,And Z-Index Properties Have No Effect)
#
# - 2. **Relative** --> Element Is Relative To Itself.(The Top, Right, Bottom, Left, And Z-Index Will Work)
#
# - 3. **Absolute** ---> Positioned Relative TO Its Closets Postitioned Ancestor(Removed From The Flow)
#
# - 4. **Fixed**--> Positioned Relative TO Browser.(Removed From Flow)
# - Top:0px --> Asel Ther Scroll Kartana Te Pan Scroll Honer
#
# - 5. **Sticky** --> Position Based On User Scoll Position
#
# - 6. **Z-Index** ---> Ith Jar Ka Don Box Overlap Zalet Box1 Boz2 Var Ahe Tar Aaplyala Box1 Var Paheje Thar Z- INdex Use Karaych

# %% [markdown]
# # Background-Image
#
# # Background- Size -->
# - Cover / Contain/ Auto
#
# - **Cover** --> Cover No Empty Page Left (Jiska Photo Bada Hoga Or Box Small Hoga To Jitna Box Utna Image)
#
# - **Contain** -->  Fit Image Visible( In This Contain Image Small But Box Big)
#
# - **Auto** --> Defualt Mai Use Hoata Hee

# %% [markdown]
# # Level 4
#
# # Flexbox ---> Flexible Box Layout
#
# - It Is A One- Dimensonal Layout Method For Arranging Items In Rows Or Columns
#
# - flex-direction: row;            /* default */
# - flex-direction: row-reverse;
# - flex-direction: column;
# - flex-direction: column-reverse;
#
# - Mhanje Jar Ka Appl Box Aadv 4 Ahet Aplyala Ubha Pahijet Thar He Vapraych
#
# - And Reverse Mhnaje Varch Box Ghali Ani Ghalch Box Var

# %% [markdown]
# **For Flex Container**
#
# - justify-content : alignment along the main axis.
#
#    flex-start / --> Mhnje Sagal Box Left Pasun Start Honar
#    flex-end / --> Mahnje Sagal Box Right Pasun Chalu Honar
#    centre / --> Sagal Box Centre La Yenar
#    space-evenly (Space-Around , Space-Between)--> Mhnaje Give The Space Of All Boxes In Same Range
#
# - flex-wrap :nowrap / wrap / wrap-reverse
# - align-items : alignment along the cross axis.
# - align-content : alignment of space between & around the content.
#
#
#
# - **Justify-Content** He Use Karaych Jehva Aplyayla Box Right Kade Ghalvaych Asty
#
# - **Align-Items** He USe Karaych Jehva Aplayala Box Ghali Kde Ghalvaych Asty(Container Per Apply Hota Hai)

# %% [markdown]
# **For Flex Item**
#
# - **align-self** : alignment of individual along the cross axis.
#
# - **flex-grow** : how much a flex item will grow relative to the rest of the flex items if space is available.
#
# - **flex-shrink** : how much a flex item will shrink relative to the rest of the flex items if space is available.
#
# (Use Of Flex Grow And Shrink Jheva Jheva Box Madhe Space Jast Asel Theva Theva Thaytl Item Big Hoyudet And Space Kami Asel Thar Automaticlly Kami Hoyudet )

# %% [markdown]
# # Media Queries
#
# - Help Create A Responsive
#
# - @Media { Width:700px
#         Div{
#             Background-Color: Red
#         }
# }
#
#
# - So Like This We Can Use Media If You Correct Axtact 700 Put Margin Then Change Color Into Red(Width)
#
#
#
#
#
#
# Ani Jar 700 Chya Puth Gel Thar Color Change Pahije Asel Tar **Max_Width**
#
#  @media(max_width:700px) {
#     Div{
#         background-color: gray;
#     }
#  }
#
#
#
# **Use Both**
#
#  @media(Min-Width:200px) and (Max-Width:300px){
#     Div{
#         background-color: yellow;
#     }
#  }

# %% [markdown]
# # Level 5
#
# - # Transitions
#
# - **transition-property** : property you want to transition (font-size, width etc.)
#
# - **transition-duration** : 2s / 4ms ..
#
# - **transition-timing-function** : ease-in / ease-out / linear / steps ..
#
# - **transition-delay** : 2s / 4ms ..
#
#
#
#
# div{
#     height: 150px;
#     width: 150px;
#     background-color: brown;
#     border: 2px solid black;
#     transition-property:all ;
#     transition-duration: 2s;
#     transition-timing-function: ease-in;
#     transition-delay: 1s;
# }
#
#
# - Shortcut
#
# Div{
#     Transition:all 2s Ease-In 1s;
# }

# %% [markdown]
# **Hover** Menas Jevha Tumi Cursal Move Karal Thya Box Varun Tech Color Change Honar
# Like - Background Color, Tech Font Color
#
# div:hover{
#     background-color: blueviolet;
#     color: white;
# }
#
#
#
# **Active** Menas Jevha Click Karal Tar Tech Color Change Honar
#
# div:active{
#     background-color: darkturquoise;
#     color: black;
# }

# %% [markdown]
# # CSS Transform
#
# Used to apply 2D & 3D transformations to an element
#
# **rotate**
#
# transform: rotate(45deg);
#
# rotate: 45deg; -->
# rotateX: 45deg; -->
# rotateY: 45deg; -->
# rotateZ: 45deg; -->
#
#
#
# div{
#     height: 150px;
#     width: 150px;
#     background-color: brown;
#     border: 2px solid black;
#     position: absolute;
#     top: 100px;
#     left: 100px;
#     transform: rotateY(180deg);
# }
#
#
#
#
# **Scale** --> Sacle Menas Size MAi Big Or Small
# Transform:Scale(2)

# %% [markdown]
# # Translate
# - Translate Menas Movie Hot Janar
#
# div{
#     height: 150px;
#     width: 150px;
#     background-color: brown;
#     border: 2px solid black;
#     position: absolute;
#     top: 100px;
#     left: 100px;
#     transition: all 2s ease-in;
# }
#
# div:hover{
#    transform: translate(50px);
#    transform: translateY(-50px);
# }
#
#
# - Ani - Minus Kel Tar Te Left Side La Move Honar
# - Y Kel Tar Var Move Honar - Kel Tar Ghali Move Honer
#
#
#
# **Every Thing In One**
#  div{
#     height: 150px;
#     width: 150px;
#     background-color: brown;
#     border: 2px solid black;
#     position: absolute;
#     top: 100px;
#     left: 100px;
#     transition: all 2s ease-in;
# }
#
# div:hover{
#    transform: translate(-50px);
#    transform: translateY(-50px);
#    transform: skew(45deg);
#    transform: rotateY(180deg);
#    transform: scale(5);
# }

# %% [markdown]
# # Amimation
#
# - Animation-Name
#
# - Animation-Duration
#
# - Animation-TIming-Function
#
# - Animation-Delay
#
# - Animation-Iteration-Count
#
# - Animation - Direction
#                 Normal/ Reverse/ Alternat/ Alternat-Reverse
#
#
#
#
#
# To Animate CSS Elements
#
# @Keyframe Myname{
#     From {Font-Size:20px}
#     To{Font-Size:40px}
#
# }
#
#
#
#  div{
#     height: 150px;
#     width: 150px;
#     border-radius: 25px;
#     background-color: brown;
#     border: 2px solid black;
#     position: absolute;
#     top: 100px;
#     left: 100px;
#     animation-name: ColorAnimate;
#     animation-duration: 0.3s;
#     animation-timing-function: ease-in;
#     animation-delay: 0s;
#     animation-iteration-count: infinite;
#  }
#
#  @keyframes ColorAnimate{
#     From {background-color:  brown;}
#     To{ background-color: rgb(76, 0, 255);}
#
#  }
#
#
#
#
#
#
# **Shortcut** In One Line
#
# Animation: Myname 2s Linear 3s Ease-In 0s Infinity Normal
